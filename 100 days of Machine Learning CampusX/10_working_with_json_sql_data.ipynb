# %% [markdown]
# ---
#
# # ***`Working with JSON/SQL Data`***
#
# ---

# %% [markdown]
# ### **Load the `JSON` Data**
#
# - Here is [dataset](https://www.kaggle.com/datasets/kaggle/recipe-ingredients-dataset/data?select=train.json).

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_json('./data/train.json')
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %% [markdown]
# ### **Load `JSON` data from `URL`**

# %%
df = pd.read_json('https://api.exchangerate-api.com/v4/latest/PKR')
df.head()
# Out:
#                              provider  \
# PKR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# PKR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# PKR  https://www.exchangerate-api.com/terms  PKR 2025-02-25
# AED  https://www.exchangerate-api.com/terms  PKR 2025-02-25
# AFN  https://www.exchangerate-api.com/terms  PKR 2025-02-25
# ALL  https://www.exchangerate-api.com/terms  PKR 2025-02-25
# AMD  https://www.exchangerate-api.com/terms  PKR 2025-02-25
#
#      time_last_updated   rates
# PKR         1740441602  1.0000
# ...

# %% [markdown]
# ### **Load the `SQL` Data**
#
# 1.  First install this library
#
#     ```bash
#     pip install mysql-connector-python
#     ```
#
# 2.  Here is [dataset](https://www.kaggle.com/datasets/busielmorley/worldcities-pop-lang-rank-sql-create-tbls). Download it.
#
# 3.  Add it to the mysql database in your system.
#
# 4. Download `XAMP`  and install it.
#
# 5. Start `Apache` and `MySQL`.
#
# ![xamp.JPG](attachment:xamp.JPG)
#
# 6. Then access this  `URL` in your BROWSER:
#
#     ```
#     http://localhost/phpmyadmin/
#     ```
# ![xamp 2.JPG](<attachment:xamp 2.JPG>)
#
#
# 7. Create new database
#
# ![xamp 3.JPG](<attachment:xamp 3.JPG>)
#
# ![xamp 4.JPG](<attachment:xamp 4.JPG>)
#
# 8. Import downloaded data
#
# ![xamp 5.JPG](<attachment:xamp 5.JPG>)
#
# 9. You can see the database created successfully
#
# ![xamp 6.JPG](<attachment:xamp 6.JPG>)

# %%
# import mysql.connector for connection
import mysql.connector

# %%
# create a connection to your database

conn = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "",
    database = "world"
)

# %%
# this requires the predefined connection in our case `conn` and an sql query 
df = pd.read_sql_query("SELECT * FROM city",conn)
df.head()
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %%
# suppose if we need country table from our db then
df = pd.read_sql_query("SELECT * FROM country",conn)
df.head()
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# ...

# %%
# suppose if we need country table from our db then
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
df.head()
# Out:
#   CountryCode    Language IsOfficial  Percentage
# 0         ABW       Dutch          T         5.3
# 1         ABW     English          F         9.5
# 2         ABW  Papiamento          F        76.7
# 3         ABW     Spanish          F         7.4
# 4         AFG     Balochi          F         0.9

# %% [markdown]
# ---
