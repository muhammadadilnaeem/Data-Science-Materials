# %% [markdown]
# ---
#
# ### **DBSCAN Clustring**
#
# ---

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# %%
X,y = make_moons(n_samples=250, noise=0.05)

# %%
X[:10]
# Out:
# array([[-0.83855578,  0.54652602],
#        [ 0.92288148,  0.1757419 ],
#        [ 0.05463521,  0.1302237 ],
#        [-0.55463707,  0.65392352],
#        [ 0.14216297,  1.09141113],
#        [ 0.78463452, -0.5548581 ],
#        [ 2.02079101,  0.30148692],
#        [ 0.36588811, -0.21852975],
#        [ 0.95617515,  0.1735934 ],
#        [-0.31599624,  1.04051748]])

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
# feature scling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
# dbscan clustring
dbscan = DBSCAN(eps=0.5)
dbscan.fit(X_scaled)
dbscan.labels_
plt.scatter(X[:,0],X[:,1],c=dbscan.labels_)
plt.show()

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %% [markdown]
# ----
