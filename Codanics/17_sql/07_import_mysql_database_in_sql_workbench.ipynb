# %% [markdown]
# ------------
#
# ## **Import Mysql Database in Sql Workbench**
#
#
# ------------

# %% [markdown]
# - First we need to download data.
#
# ![sql_79.JPG](attachment:sql_79.JPG)
#
# - After Extracting ZIP file our data file will look like this
#
# ![sql_80.JPG](attachment:sql_80.JPG)
#
# - Now we need to open our Mysql Workbench and load the sql data with this option;
#
# ![sql_81.JPG](attachment:sql_81.JPG)
#
# ![sql_81.5.JPG](attachment:sql_81.5.JPG)
#
# - This is how our data file will look like;
#
# ![sql_82.JPG](attachment:sql_82.JPG)
#
# - Now we need to run the file in order to create a database in our system using this;
#
# ![sql_83.JPG](attachment:sql_83.JPG)
#
# - After refreshing you will see this kind of output;
#
# ![sql_84.JPG](attachment:sql_84.JPG)
#
# - Our Customer table will look like this;
#
# ![sql_85.JPG](attachment:sql_85.JPG)
#
# - Let's run a querry, as we can see the result's of query;
#
# ![sql_86.JPG](attachment:sql_86.JPG)
#
# - We can also export some data from sql workbench to work on it externaly.
#
# ![sql_87.JPG](attachment:sql_87.JPG)
#
# ![sql_88.JPG](attachment:sql_88.JPG)
#
#
# - We can further work on data;
#
# ![sql_89.JPG](attachment:sql_89.JPG)
#
# - So this is it.
#
# ---------
