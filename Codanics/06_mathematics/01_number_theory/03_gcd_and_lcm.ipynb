# %% [markdown]
# ----
#
# # ***`🌟 Understanding GCD and LCM in Mathematics 📏🔢`***
#
# ![lcm 1.JPG](<attachment:lcm 1.JPG>)
#
# ![lcm 2.JPG](<attachment:lcm 2.JPG>)
#
# ![lcm 3.JPG](<attachment:lcm 3.JPG>)
#
# ![lcm 4.JPG](<attachment:lcm 4.JPG>)
#
# ![lcm 5.JPG](<attachment:lcm 5.JPG>)
#
# ![lcm 6.JPG](<attachment:lcm 6.JPG>)
#
# ![lcm 7.JPG](<attachment:lcm 7.JPG>)
#
# ![lcm 8.JPG](<attachment:lcm 8.JPG>)
#
# ![lcm 9.JPG](<attachment:lcm 9.JPG>)
#
#
# ----
